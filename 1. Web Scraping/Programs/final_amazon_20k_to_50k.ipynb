# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
from urllib.parse import urljoin
from datetime import datetime

def get_title(soup):
    try:
        # Outer Tag 
        title = soup.find("span", attrs={"id":'productTitle'})
        
        # Inner String Object
        title_value = title.text
        # Title as a string value
        title_string = title_value.strip()
    except AttributeError:
        title_string = ""
    return title_string

def get_price(soup):
    try:
        price_tag = soup.select_one("span.a-price span.a-offscreen")
        if price_tag and price_tag.text.strip():
            price_text = price_tag.text.strip()
        elif soup.find("span", {"id": "priceblock_ourprice"}):
            price_text = soup.find("span", {"id": "priceblock_ourprice"}).text.strip()
        elif soup.find("span", {"id": "priceblock_dealprice"}):
            price_text = soup.find("span", {"id": "priceblock_dealprice"}).text.strip()
        elif soup.find("span", {"id": "priceToPay"}):
            price_text = soup.find("span", {"id": "priceToPay"}).text.strip()
        elif soup.select_one("span.a-price-whole"):
            whole = soup.select_one("span.a-price-whole").text.replace(",", "").strip()
            fraction_tag = soup.select_one("span.a-price-fraction")
            fraction = fraction_tag.text.strip() if fraction_tag else "00"
            price_text = f"{whole}.{fraction}"
        else:
            return None
        cleaned_price = (
            price_text
            .replace("₹", "")
            .replace(",", "")
            .strip()
                )
        
        return float(cleaned_price)
        
    except Exception:
        return None

def get_rating(soup):
    try:
        rating = soup.find("span", {"class": "a-icon-alt"})
        return rating.text.split(" ")[0]
    except:
        return ""


def get_review_count(soup):
    try:
        # Method 1: Standard review count selector
        review = soup.find("span", {"id": "acrCustomerReviewText"})
        if review:
            review_text = review.text.strip()
            # Brackets aur commas removing
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 2: Alternative selector for reviews
        review_alt = soup.select_one("#acrCustomerReviewLink span")
        if review_alt:
            review_text = review_alt.text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 3: Another common pattern
        review_count = soup.find("a", {"data-hook": "see-all-reviews-link-foot"})
        if review_count:
            review_text = review_count.find("span").text.strip()
            review_number = review_text.split(" ")[0]
            review_number = review_number.replace(",", "").replace("(", "").replace(")", "")
            return int(review_number)
        
        # Method 4: Checking if reviews mentioned in rating link or not
        rating_link = soup.find("a", {"id": "acrCustomerReviewLink"})
        if rating_link:
            review_text = rating_link.text.strip()
            # "4.5 out of 5 stars    2,031 ratings" for hanlding these formats
            parts = review_text.split()
            for part in parts:
                cleaned = part.replace(",", "").replace("(", "").replace(")", "")
                if cleaned.isdigit():
                    num = int(cleaned)
                    if num > 10:  # Rating cannot be more than 10 so it must be reviews
                        return num
            
        return 0  # if no review found then returning 0
        
    except Exception as e:
        print(f"Review scraping error: {e}")
        return 0

def get_availability(soup):
    try:
        available = soup.find("div", attrs={'id':'availability'})
        available = available.find("span").string.strip()
    except AttributeError:
        available = "Not Available"	
    return available

def get_discount(soup):
    try:
        discount = soup.find("span", {"class": "savingsPercentage"})
        if discount:
            return discount.text.replace("%", "").replace("-", "").strip()
        return ""
    except:
        return ""

def get_brand(soup):
    try:
        brand = soup.find("a", {"id": "bylineInfo"})
        if brand:
            return brand.text.replace("Visit the", "").replace("Store", "").strip()
        # Alternative method
        brand_alt = soup.find("span", {"class": "a-size-base po-break-word"})
        if brand_alt:
            return brand_alt.text.strip()
        return ""
    except:
        return ""

# %%
if __name__ == '__main__':
    HEADERS = ({'User-Agent':'',
            'Accept-Language': 'en-US, en;q=0.5'})
    BASE_URL = "https://www.amazon.in"
    
    # defining price range
    MIN_PRICE = 20000
    MAX_PRICE = 50000
    TOTAL_PAGES = 15
    PRICE_LABEL = "20k-50k"
    
    print(f"Amazon Smartphone Scraper - {PRICE_LABEL}")
    print(f"Price Range: ₹{MIN_PRICE:,} - ₹{MAX_PRICE:,}")
    print(f"Pages to Scrape: {TOTAL_PAGES}")
    
    product_links = []
    
    # Step 1: Collect all product links
    for page in range(1, TOTAL_PAGES + 1):
        print(f"\nScraping search page {page}/{TOTAL_PAGES}...")
        
        search_url = f"https://www.amazon.in/s?k=smartphones+20k+to+50k&crid=1KDJ44NP04IMB&sprefix=smartphones+20k+to+0k%2Caps%2C380&ref=nb_sb_noss&page={page}"
        
        try:
            response = requests.get(search_url, headers=HEADERS, timeout=10)
            if response.status_code != 200:
                print(f"Page {page} failed with status code: {response.status_code}")
                continue
        except requests.exceptions.RequestException as e:
            print(f"Page {page} request failed: {e}")
            continue
        
        soup = BeautifulSoup(response.content, "html.parser")
        
        links = soup.find_all("a", attrs={'class':'a-link-normal s-no-outline'})
                               
        for link in links:
            href = link.get("href")
            if href and "/dp/" in href:
                product_links.append(href.split("?")[0])
        
        print(f"  ✓ Found {len(links)} products on page {page}")
        time.sleep(2)  
    
    # Remove duplicates
    product_links = list(set(product_links))
    print(f"\nTotal unique products found: {len(product_links)}")
    
    # Step 2: Initialize data dictionary
    data = {
        "title": [],
        "price": [],
        "rating": [],
        "reviews": [],
        "discount": [],
        "brand": [],
        "product_url": []
    }
    
    # Step 3: Scrape each product
    print(f"\nStarting to scrape {len(product_links)} products...")
    print("="*60)
    
    successful_scrapes = 0
    failed_scrapes = 0
    
    for idx, link in enumerate(product_links, start=1):
        product_url = urljoin(BASE_URL, link)
        print(f"[{idx}/{len(product_links)}] Scraping product...")
        
        try:
            product_page = requests.get(product_url, headers=HEADERS, timeout=10)
            if product_page.status_code != 200:
                print(f"Failed - Status code: {product_page.status_code}")
                failed_scrapes += 1
                continue
        except Exception as e:
            print(f"Failed - Request error: {e}")
            failed_scrapes += 1
            continue
        
        product_soup = BeautifulSoup(product_page.content, "html.parser")
        
        try:
            title = get_title(product_soup)
            cleaned_price = get_price(product_soup)
            rating = get_rating(product_soup)
            reviews = get_review_count(product_soup)
            discount = get_discount(product_soup)
            brand = get_brand(product_soup)
            
            # Data appending
            data["title"].append(title)
            data["price"].append(cleaned_price)
            data["rating"].append(rating)
            data["reviews"].append(reviews)
            data["discount"].append(discount)
            data["brand"].append(brand)
            data["product_url"].append(product_url)
            
            # Success message with key details
            print(f"  ✓ Success - {title[:50]}... | Price: ₹{cleaned_price} | Reviews: {reviews}")
            successful_scrapes += 1
            
        except Exception as e:
            print(f"Failed - Data extraction error: {e}")
            failed_scrapes += 1
            continue
        
        time.sleep(2)  
    
    print("Creating DataFrame...")
    amazon_df = pd.DataFrame.from_dict(data)
    
    # Converting to proper data types
    amazon_df["price"] = pd.to_numeric(amazon_df["price"], errors="coerce")
    amazon_df["rating"] = pd.to_numeric(amazon_df["rating"], errors="coerce")
    amazon_df["reviews"] = pd.to_numeric(amazon_df["reviews"], errors="coerce")
    amazon_df["discount"] = pd.to_numeric(amazon_df["discount"], errors="coerce")
    
    # Step 5: Save to CSV
    csv_filename = f"amazon_smartphones_20k_to_50k.csv"
    amazon_df.to_csv(csv_filename, index=False, encoding='utf-8-sig')
    print("Completed")
# Out:
# Amazon Smartphone Scraper - 20k-50k
# Price Range: ₹20,000 - ₹50,000
# Pages to Scrape: 15
#
# Scraping search page 1/15...
#   ✓ Found 27 products on page 1
#
# Scraping search page 2/15...
#   ✓ Found 22 products on page 2
#
# Scraping search page 3/15...
#   ✓ Found 22 products on page 3
#
# Scraping search page 4/15...
#   ✓ Found 22 products on page 4
#
# Scraping search page 5/15...
#   ✓ Found 10 products on page 5
#
# Scraping search page 6/15...
#   ✓ Found 6 products on page 6
#
# Scraping search page 7/15...
#   ✓ Found 5 products on page 7
#
# Scraping search page 8/15...
#   ✓ Found 6 products on page 8
#
# Scraping search page 9/15...
#   ✓ Found 6 products on page 9
#
# Scraping search page 10/15...
#   ✓ Found 6 products on page 10
#
# Scraping search page 11/15...
#   ✓ Found 6 products on page 11
#
# Scraping search page 12/15...
#   ✓ Found 6 products on page 12
#
# Scraping search page 13/15...
#   ✓ Found 6 products on page 13
#
# Scraping search page 14/15...
#   ✓ Found 6 products on page 14
#
# Scraping search page 15/15...
#   ✓ Found 6 products on page 15
#
# Total unique products found: 68
#
# Starting to scrape 68 products...
# ============================================================
# [1/68] Scraping product...
#   ✓ Success - Oppo F25 Pro 5G (Lava Red, 8GB RAM, 128GB Storage)... | Price: ₹28999.0 | Reviews: 530
# [2/68] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Ultra 5G (Titanium Silverblue, ... | Price: ₹119999.0 | Reviews: 2
# [3/68] Scraping product...
#   ✓ Success - REDMI Note 15 Pro 5G (Silver Ash 8GB+256GB) | 200M... | Price: ₹31999.0 | Reviews: 182
# [4/68] Scraping product...
#   ✓ Success - realme 16 5G Smartphone 8+256GB Air White, 7000mAh... | Price: ₹33999.0 | Reviews: 890
# [5/68] Scraping product...
#   ✓ Success - Wobble One 5G (12GB+256GB) | 50MP Epic Front Camer... | Price: ₹29999.0 | Reviews: 13
# [6/68] Scraping product...
#   ✓ Success - iQOO Z10R 5G (Aquamarine, 8GB RAM, 256GB Storage) ... | Price: ₹24999.0 | Reviews: 3925
# [7/68] Scraping product...
#   ✓ Success - iQOO 15R (Triumph Silver, 8GB RAM, 256GB Storage) ... | Price: ₹46999.0 | Reviews: 429
# [8/68] Scraping product...
#   ✓ Success - Motorola Edge 50 Fusion 5G (Hot Pink, 12GB RAM, 25... | Price: ₹23649.0 | Reviews: 755
# [9/68] Scraping product...
#   ✓ Success - realme 15 Pro 5G (Flowing Silver, 8GB RAM, 256GB S... | Price: ₹32960.0 | Reviews: 550
# [10/68] Scraping product...
#   ✓ Success - realme GT7 Pro 5G Smartphone 16+512 Galaxy Grey, 6... | Price: ₹68900.0 | Reviews: 19
# [11/68] Scraping product...
#   ✓ Success - realme 16 Pro 5G Smartphone 12+256GB Orchid Purple... | Price: ₹40999.0 | Reviews: 346
# [12/68] Scraping product...
#   ✓ Success - realme 16 Pro+ 5G Smartphone 8+256GB Grey, 144Hz A... | Price: ₹45999.0 | Reviews: 623
# [13/68] Scraping product...
#   ✓ Success - Redmi Note 14 Pro+ 5G (Phantom Purple, 8GB RAM+ 25... | Price: ₹27999.0 | Reviews: 10
# [14/68] Scraping product...
#   ✓ Success - Samsung Galaxy S24 FE 5G (Graphite, 8GB RAM, 256GB... | Price: ₹53999.0 | Reviews: 336
# [15/68] Scraping product...
#   ✓ Success - REDMI Note 15 5G (Mist Purple, 8GB RAM 128GB Stora... | Price: ₹24999.0 | Reviews: 543
# [16/68] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8GB RAM 256GB ROM, 6.8 in... | Price: ₹22999.0 | Reviews: 233
# [17/68] Scraping product...
#   ✓ Success - Redmi Note 14 Pro+ 5G (Titan Black, 8GB RAM+ 256GB... | Price: ₹27999.0 | Reviews: 29
# [18/68] Scraping product...
#   ✓ Success - realme 15 5G Smartphone 8+256GB Silver,144Hz Hyper... | Price: ₹31999.0 | Reviews: 564
# [19/68] Scraping product...
#   ✓ Success - vivo V70 FE 5G (Monsoon Blue, 8GB RAM, 128GB Stora... | Price: ₹37999.0 | Reviews: 0
# [20/68] Scraping product...
#   ✓ Success - Nothing Phone (3a) Lite 5G (White, 8GB RAM, 256GB ... | Price: ₹24370.0 | Reviews: 5285
# [21/68] Scraping product...
#   ✓ Success - realme 15 Pro 5G Smartphone 12+256GB Green,4K 60FP... | Price: ₹37999.0 | Reviews: 509
# [22/68] Scraping product...
#   ✓ Success - Wobble One 5G (8GB+128GB) | 50MP Epic Front Camera... | Price: ₹26999.0 | Reviews: 0
# [23/68] Scraping product...
#   ✓ Success - POVA Curve 5G (Magic Silver, 8GB+256GB)... | Price: ₹19999.0 | Reviews: 282
# [24/68] Scraping product...
#   ✓ Success - realme 15T 5G Smartphone 8+256GB 6.67inch Screen, ... | Price: ₹28999.0 | Reviews: 181
# [25/68] Scraping product...
#   ✓ Success - OnePlus 10R 5G (Forest Green, 8GB RAM, 128GB Stora... | Price: ₹29999.0 | Reviews: 12906
# [26/68] Scraping product...
#   ✓ Success - OnePlus 13R | Smarter with OnePlus AI (12GB RAM, 2... | Price: ₹41999.0 | Reviews: 4228
# [27/68] Scraping product...
#   ✓ Success - Motorola Edge 60 Fusion 5G Smartphone with 6.67" 1... | Price: ₹25399.0 | Reviews: 1279
# [28/68] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Black, 8GB, 256GB)_... | Price: ₹33999.0 | Reviews: 625
# [29/68] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹59999.0 | Reviews: 141
# [30/68] Scraping product...
#   ✓ Success - REDMI Note 15 Pro+ 5G (Coffee Mocha, 8GB + 256GB) ... | Price: ₹37999.0 | Reviews: 185
# [31/68] Scraping product...
#   ✓ Success - Motorola Edge 70 Fusion 5G (Pantone Country Air, 8... | Price: ₹26999.0 | Reviews: 0
# [32/68] Scraping product...
#   ✓ Success - Nothing Phone (3A) 5G (Blue, 8GB RAM, 128GB Storag... | Price: ₹24999.0 | Reviews: 108
# [33/68] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8+256GB Marine Blue, 6.8-... | Price: ₹18999.0 | Reviews: 808
# [34/68] Scraping product...
#   ✓ Success - Motorola Edge 70 (Grey, 8GB RAM, 256GB Storage)... | Price: ₹30962.0 | Reviews: 45
# [35/68] Scraping product...
#   ✓ Success - Samsung Galaxy S24 5G AI Smartphone (Cobalt Violet... | Price: ₹44794.0 | Reviews: 924
# [36/68] Scraping product...
#   ✓ Success - Samsung Galaxy S25 Ultra 5G AI Smartphone (Titaniu... | Price: ₹110999.0 | Reviews: 1065
# [37/68] Scraping product...
#   ✓ Success - iQOO 15 (Alpha, 16GB RAM, 512GB Storage) | Fastest... | Price: ₹79999.0 | Reviews: 635
# [38/68] Scraping product...
#   ✓ Success - OnePlus Nord 3 5G (Tempest Gray, 8GB RAM, 128GB St... | Price: ₹33699.0 | Reviews: 8106
# [39/68] Scraping product...
#   ✓ Success - Oppo Reno15Pro 5G (Sunset Gold 12GB RAM, 256GB Sto... | Price: ₹67999.0 | Reviews: 45
# [40/68] Scraping product...
#   ✓ Success - realme 15X 5G Smartphone 8+256GB, 6.8-inch Screen,... | Price: ₹26999.0 | Reviews: 340
# [41/68] Scraping product...
#   ✓ Success - Samsung Galaxy A57 5G (Awesome Navy, 8GB RAM, 256G... | Price: ₹53900.0 | Reviews: 0
# [42/68] Scraping product...
#   ✓ Success - realme 16 Pro+ 5G Smartphone 12+256GB, 144Hz AMOLE... | Price: ₹49999.0 | Reviews: 241
# [43/68] Scraping product...
#   ✓ Success - Samsung Galaxy A36 5G (Awesome Lime, 8GB, 256GB) |... | Price: ₹38999.0 | Reviews: 0
# [44/68] Scraping product...
#   ✓ Success - Nothing Phone 4a (8GB 128GB Black)... | Price: ₹33490.0 | Reviews: 2
# [45/68] Scraping product...
#   ✓ Success - realme NARZO Power 5G (Titan Silver,8GB+256GB) 100... | Price: ₹28999.0 | Reviews: 29
# [46/68] Scraping product...
#   ✓ Success - realme GT 6T 5G (Fluid Silver,8GB RAM+128GB Storag... | Price: ₹27999.0 | Reviews: 701
# [47/68] Scraping product...
#   ✓ Success - realme 16 5G Smartphone 12+256GB Air Black, 7000mA... | Price: ₹36999.0 | Reviews: 890
# [48/68] Scraping product...
#   ✓ Success - iQOO 9 Pro 5G (Dark Cruise, 12GB RAM, 256GB Storag... | Price: ₹49999.0 | Reviews: 365
# [49/68] Scraping product...
#   ✓ Success - realme 16 5G Smartphone 12+256GB Air White, 7000mA... | Price: ₹36999.0 | Reviews: 890
# [50/68] Scraping product...
#   ✓ Success - realme Smartphone 15 pro 5G, 12GB RAM 256GB ROM 6.... | Price: ₹35999.0 | Reviews: 107
# [51/68] Scraping product...
#   ✓ Success - Nothing Phone (3a) 5G (8GB RAM + 128GB Storage) (W... | Price: ₹25990.0 | Reviews: 526
# [52/68] Scraping product...
#   ✓ Success - Samsung Galaxy S24 FE 5G AI Smartphone (Mint, 8GB ... | Price: ₹39999.0 | Reviews: 949
# [53/68] Scraping product...
#   ✓ Success - Samsung Galaxy S24 FE 5G AI Smartphone (Blue, 8GB ... | Price: ₹39999.0 | Reviews: 804
# [54/68] Scraping product...
#   ✓ Success - realme GT 7 (IceSense Black,8GB+256GB) | India's 1... | Price: ₹39990.0 | Reviews: 350
# [55/68] Scraping product...
#   ✓ Success - Nothing Phone 4a (8GB 256GB Blue)... | Price: ₹34999.0 | Reviews: 0
# [56/68] Scraping product...
#   ✓ Success - iQOO 15R (Triumph Silver, 12GB RAM, 256GB Storage)... | Price: ₹50999.0 | Reviews: 429
# [57/68] Scraping product...
#   ✓ Success - OnePlus 15 | 12GB+256GB | Infinite Black | India's... | Price: ₹72999.0 | Reviews: 981
# [58/68] Scraping product...
#   ✓ Success - Oppo Reno 11 Pro 5G (Rock Grey, 12GB RAM+ 256GB St... | Price: ₹36800.0 | Reviews: 49
# [59/68] Scraping product...
#   ✓ Success - Edge 50 Pro 5G 125W Charger 12GB RAM, 256GB Storag... | Price: ₹25999.0 | Reviews: 0
# [60/68] Scraping product...
#   ✓ Success - Samsung Galaxy S25 FE 5G Smartphone with Galaxy AI... | Price: ₹56200.0 | Reviews: 141
# [61/68] Scraping product...
#   ✓ Success - Nothing Phone (4a) Pro (Black, 8GB, 256GB)... | Price: ₹48999.0 | Reviews: 0
# [62/68] Scraping product...
#   ✓ Success - OnePlus Nord 5 | Snapdragon 8s Gen 3 | Stable 144F... | Price: ₹33999.0 | Reviews: 5038
# [63/68] Scraping product...
#   ✓ Success - OnePlus 11 5G (Eternal Green, 8GB RAM, 128GB Stora... | Price: ₹34950.0 | Reviews: 6748
# [64/68] Scraping product...
#   ✓ Success - Oppo A79 5G (Mystery Black, 8GB RAM, 128GB Storage... | Price: ₹19200.0 | Reviews: 618
# [65/68] Scraping product...
#   ✓ Success - OnePlus 15R | 12GB+512GB | Mint Breeze | World's F... | Price: ₹55499.0 | Reviews: 1031
# [66/68] Scraping product...
#   ✓ Success - Samsung Galaxy S25+ 5G AI Smartphone (Navy, 12GB R... | Price: ₹84999.0 | Reviews: 359
# [67/68] Scraping product...
#   ✓ Success - vivo Y300 Plus 5G (Silk Green, 8GB RAM, 128GB Stor... | Price: ₹23999.0 | Reviews: 47
# [68/68] Scraping product...
#   ✓ Success - iQOO 9 Pro 5G (Legend, 8GB RAM, 256GB Storage) | S... | Price: ₹44999.0 | Reviews: 1293
# Creating DataFrame...
# Completed
